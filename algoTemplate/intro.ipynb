# %% [markdown]
# # 1. Introduction
#
# ## As part of my continuous exploration of algorithms and machine learning, I have created two detailed templates:
# - <u> Algorithm Template </u>: Contains fundamental data structures and algorithms implemented in C++, Python, and Java
# - <u> Machine Learning Template</u>: Implements core supervised and unsupervised learning techniques from scratch in Python
#
# ## My motivation for these projects was to deepen my understanding of each algorithm and learning model by building them manually without relying on libraries.</p>
